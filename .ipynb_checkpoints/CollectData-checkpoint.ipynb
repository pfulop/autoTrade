# %%
import json
import urllib.request
import time
import pandas as pd
from time import sleep
import datetime

# %%
base_url = 'https://min-api.cryptocompare.com/'

# %%
def get_info(time, currency, currency2='USD'):
    data = json.load(urllib.request.urlopen(base_url + f'data/histominute?fsym={currency}&tsym={currency2}&limit=60&e=CCCAGG&toTs={time}'))
    return data

# %%
get_info('1514463240','BTC')
# Out:
# {'Aggregated': False,
#  'ConversionType': {'conversionSymbol': '', 'type': 'direct'},
#  'Data': [{'close': 13679.21,
#    'high': 13709.92,
#    'low': 13672.21,
#    'open': 13706.65,
#    'time': 1514459640,
#    'volumefrom': 254.1,
#    'volumeto': 3495818.07},
#   {'close': 13631.91,
#    'high': 13685.2,
#    'low': 13631.19,
#    'open': 13677.05,
#    'time': 1514459700,
#    'volumefrom': 208.54,
#    'volumeto': 2861297.36},
#   {'close': 13614.61,
#    'high': 13640.95,
#    'low': 13591.27,
#    'open': 13640.95,
#    'time': 1514459760,
#    'volumefrom': 286.33,
#    'volumeto': 3902400.54},
#   {'close': 13649.18,
#    'high': 13654.69,
#    'low': 13616.33,
#    'open': 13616.33,
#    'time': 1514459820,
#    'volumefrom': 187.36,
#    'volumeto': 2558197.35},
#   {'close': 13695.25,
#    'high': 13707.92,
#    'low': 13645.44,
#    'open': 13652.86,
#    'time': 1514459880,
#    'volumefrom': 134.31,
#    'volumeto': 1838842.05},
#   {'close': 13668.48,
#    'high': 13700.03,
#    'low': 13658.06,
#    'open': 13695.39,
#    'time': 1514459940,
#    'volumefrom': 85.82,
#    'volumeto': 1180453.01},
#   {'close': 13655.97,
#    'high': 13674.9,
#    'low': 13646.71,
#    'open': 13668.48,
#    'time': 1514460000,
#    'volumefrom': 68.8,
#    'volumeto': 959434.78},
#   {'close': 13668.03,
#    'high': 13670.18,
#    'low': 13645.63,
#    'open': 13655.97,
#    'time': 1514460060,
#    'volumefrom': 95.81,
#    'volumeto': 1313627.03},
#   {'close': 13670.26,
#    'high': 13688,
#    'low': 13667.06,
#    'open': 13668.03,
#    'time': 1514460120,
#    'volumefrom': 110.02,
#    'volumeto': 1522817.45},
#   {'close': 13700.31,
#    'high': 13700.75,
#    'low': 13670.26,
#    'open': 13671.3,
#    'time': 1514460180,
#    'volumefrom': 86.83,
#    'volumeto': 1186341.34},
#   {'close': 13765.88,
#    'high': 13777.09,
#    'low': 13700.31,
#    'open': 13700.31,
#    'time': 1514460240,
#    'volumefrom': 258.1,
#    'volumeto': 3535928.97},
#   {'close': 13785.73,
#    'high': 13799.06,
#    'low': 13746.88,
#    'open': 13768.44,
#    'time': 1514460300,
#    'volumefrom': 208.27,
#    'volumeto': 2864313.18},
#   {'close': 13734.53,
#    'high': 13786.51,
#    'low': 13723.05,
#    'open': 13785.73,
#    'time': 1514460360,
#    'volumefrom': 133.76,
#    'volumeto': 1842094.48},
#   {'close': 13761.13,
#    'high': 13764.76,
#    'low': 13712.26,
#    'open': 13731,
#    'time': 1514460420,
#    'volumefrom': 115.82,
#    'volumeto': 1594622.64},
#   {'close': 13784.9,
#    'high': 13790.28,
#    'low': 13744.08,
#    'open': 13761.13,
#    'time': 1514460480,
#    'volumefrom': 154.93,
#    'volumeto': 2154918.7},
#   {'close': 13763.05,
#    'high': 13785.3,
#    'low': 13751.24,
#    'open': 13785.3,
#    'time': 1514460540,
#    'volumefrom': 86.86,
#    'volumeto': 1202153.78},
#   {'close': 13776.82,
#    'high': 13778.51,
#    'low': 13756.28,
#    'open': 13765.34,
#    'time': 1514460600,
#    'volumefrom': 105.3,
#    'volumeto': 1449397.7},
#   {'close': 13766.96,
#    'high': 13792.1,
#    'low': 13760.59,
#    'open': 13776.82,
#    'time': 1514460660,
#    'volumefrom': 155.29,
#    'volumeto': 2147759.47},
#   {'close': 13738.57,
#    'high': 13764.1,
#    'low': 13729.59,
#    'open': 13761.31,
#    'time': 1514460720,
#    'volumefrom': 76.15,
#    'volumeto': 1053765.11},
#   {'close': 13724.13,
#    'high': 13740.39,
#    'low': 13717.27,
#    'open': 13738.57,
#    'time': 1514460780,
#    'volumefrom': 119.78,
#    'volumeto': 1654517.67},
#   {'close': 13661.74,
#    'high': 13723.76,
#    'low': 13656.37,
#    'open': 13722.03,
#    'time': 1514460840,
#    'volumefrom': 209.07,
#    'volumeto': 2897918.8},
#   {'close': 13682.06,
#    'high': 13698.62,
#    'low': 13642.26,
#    'open': 13661.74,
#    'time': 1514460900,
#    'volumefrom': 171.26,
#    'volumeto': 2345722.55},
#   {'close': 13641.4,
#    'high': 13683.46,
#    'low': 13632.15,
#    'open': 13682.06,
#    'time': 1514460960,
#    'volumefrom': 96.51,
#    'volumeto': 1323662.78},
#   {'close': 13643.36,
#    'high': 13676.86,
#    'low': 13639.43,
#    'open': 13641.26,
#    'time': 1514461020,
#    'volumefrom': 90.93,
#    'volumeto': 1251004.82},
#   {'close': 13632.45,
#    'high': 13643.03,
#    'low': 13604.08,
#    'open': 13643.03,
#    'time': 1514461080,
#    'volumefrom': 147.26,
#    'volumeto': 2016333.49},
#   {'close': 13651.91,
#    'high': 13653.22,
#    'low': 13614.22,
#    'open': 13634.63,
#    'time': 1514461140,
#    'volumefrom': 96.31,
#    'volumeto': 1323255.2},
#   {'close': 13728.74,
#    'high': 13728.74,
#    'low': 13642.28,
#    'open': 13656.2,
#    'time': 1514461200,
#    'volumefrom': 139.42,
#    'volumeto': 1921255.28},
#   {'close': 13762.27,
#    'high': 13771.13,
#    'low': 13718.57,
#    'open': 13728.74,
#    'time': 1514461260,
#    'volumefrom': 107.17,
#    'volumeto': 1477902.45},
#   {'close': 13760.08,
#    'high': 13768.68,
#    'low': 13750.51,
#    'open': 13762.5,
#    'time': 1514461320,
#    'volumefrom': 56.48,
#    'volumeto': 792603.28},
#   {'close': 13751.77,
#    'high': 13760.52,
#    'low': 13739.75,
#    'open': 13760.52,
#    'time': 1514461380,
#    'volumefrom': 61.47,
#    'volumeto': 846320.43},
#   {'close': 13776.57,
#    'high': 13777.44,
#    'low': 13729.87,
#    'open': 13751.94,
#    'time': 1514461440,
#    'volumefrom': 66.84,
#    'volumeto': 941667.88},
#   {'close': 13774.09,
#    'high': 13781.41,
#    'low': 13758.47,
#    'open': 13777.1,
#    'time': 1514461500,
#    'volumefrom': 102.12,
#    'volumeto': 1419686.41},
#   {'close': 13797.9,
#    'high': 13803.05,
#    'low': 13774.09,
#    'open': 13774.09,
#    'time': 1514461560,
#    'volumefrom': 114.58,
#    'volumeto': 1590028.82},
#   {'close': 13783.36,
#    'high': 13791.35,
#    'low': 13772.28,
#    'open': 13790.91,
#    'time': 1514461620,
#    'volumefrom': 52.67,
#    'volumeto': 737401.08},
#   {'close': 13768.21,
#    'high': 13791.57,
#    'low': 13764.75,
#    'open': 13783.79,
#    'time': 1514461680,
#    'volumefrom': 77.64,
#    'volumeto': 1087417.55},
#   {'close': 13757.03,
#    'high': 13781.4,
#    'low': 13754.34,
#    'open': 13768.21,
#    'time': 1514461740,
#    'volumefrom': 55.65,
#    'volumeto': 782362.02},
#   {'close': 13775.63,
#    'high': 13776.52,
#    'low': 13755.96,
#    'open': 13757.03,
#    'time': 1514461800,
#    'volumefrom': 54.45,
#    'volumeto': 751714.21},
#   {'close': 13778.39,
#    'high': 13778.67,
#    'low': 13763.61,
#    'open': 13775.63,
#    'time': 1514461860,
#    'volumefrom': 38.7,
#    'volumeto': 539081.13},
#   {'close': 13796.04,
#    'high': 13798.66,
#    'low': 13776.8,
#    'open': 13778.39,
#    'time': 1514461920,
#    'volumefrom': 114.87,
#    'volumeto': 1585019.18},
#   {'close': 13806.18,
#    'high': 13808.01,
#    'low': 13792.69,
#    'open': 13796.17,
#    'time': 1514461980,
#    'volumefrom': 59.77,
#    'volumeto': 828980.61},
#   {'close': 13808.02,
#    'high': 13814.37,
#    'low': 13803.66,
#    'open': 13806.4,
#    'time': 1514462040,
#    'volumefrom': 92.97,
#    'volumeto': 1290387.44},
#   {'close': 13873.13,
#    'high': 13873.13,
#    'low': 13812.35,
#    'open': 13812.79,
#    'time': 1514462100,
#    'volumefrom': 215.03,
#    'volumeto': 2979286.83},
#   {'close': 13895.69,
#    'high': 13895.69,
#    'low': 13871.4,
#    'open': 13871.4,
#    'time': 1514462160,
#    'volumefrom': 181.01,
#    'volumeto': 2515535.6},
#   {'close': 13867.38,
#    'high': 13896.96,
#    'low': 13866.51,
#    'open': 13895.69,
#    'time': 1514462220,
#    'volumefrom': 112.68,
#    'volumeto': 1574609.2},
#   {'close': 13882.64,
#    'high': 13882.64,
#    'low': 13861.15,
#    'open': 13867.38,
#    'time': 1514462280,
#    'volumefrom': 87.32,
#    'volumeto': 1224957.53},
#   {'close': 13888.5,
#    'high': 13891.08,
#    'low': 13878.31,
#    'open': 13878.31,
#    'time': 1514462340,
#    'volumefrom': 44.8,
#    'volumeto': 627562.86},
#   {'close': 13898.77,
#    'high': 13903.76,
#    'low': 13886.6,
#    'open': 13888.5,
#    'time': 1514462400,
#    'volumefrom': 96.52,
#    'volumeto': 1355320.3},
#   {'close': 13868.1,
#    'high': 13899.61,
#    'low': 13867.88,
#    'open': 13898.77,
#    'time': 1514462460,
#    'volumefrom': 98.53,
#    'volumeto': 1378211.57},
#   {'close': 13843.63,
#    'high': 13873.75,
#    'low': 13839.58,
#    'open': 13868.1,
#    'time': 1514462520,
#    'volumefrom': 83.69,
#    'volumeto': 1170668.51},
#   {'close': 13828.4,
#    'high': 13845.86,
#    'low': 13819.28,
#    'open': 13843.63,
#    'time': 1514462580,
#    'volumefrom': 84.42,
#    'volumeto': 1176513.07},
#   {'close': 13808.28,
#    'high': 13831.71,
#    'low': 13808.28,
#    'open': 13828.7,
#    'time': 1514462640,
#    'volumefrom': 49.39,
#    'volumeto': 686426.22},
#   {'close': 13846.49,
#    'high': 13852.59,
#    'low': 13807.84,
#    'open': 13808.28,
#    'time': 1514462700,
#    'volumefrom': 105.13,
#    'volumeto': 1458663.92},
#   {'close': 13817.56,
#    'high': 13851.61,
#    'low': 13815.92,
#    'open': 13846.49,
#    'time': 1514462760,
#    'volumefrom': 58.09,
#    'volumeto': 810747.13},
#   {'close': 13838.67,
#    'high': 13838.7,
#    'low': 13815.72,
#    'open': 13817.56,
#    'time': 1514462820,
#    'volumefrom': 54.94,
#    'volumeto': 769884.06},
#   {'close': 13823.98,
#    'high': 13848.79,
#    'low': 13820.08,
#    'open': 13842.33,
#    'time': 1514462880,
#    'volumefrom': 70.19,
#    'volumeto': 973620.08},
#   {'close': 13843.16,
#    'high': 13846.75,
#    'low': 13821.29,
#    'open': 13821.38,
#    'time': 1514462940,
#    'volumefrom': 69.91,
#    'volumeto': 969347.88},
#   {'close': 13836.85,
#    'high': 13856.82,
#    'low': 13835.58,
#    'open': 13846.88,
#    'time': 1514463000,
#    'volumefrom': 57.5,
#    'volumeto': 797496.93},
#   {'close': 13859.65,
#    'high': 13864.78,
#    'low': 13835.55,
#    'open': 13836.85,
#    'time': 1514463060,
#    'volumefrom': 159.38,
#    'volumeto': 2200602.93},
#   {'close': 13863.37,
#    'high': 13883.07,
#    'low': 13859.65,
#    'open': 13859.65,
#    'time': 1514463120,
#    'volumefrom': 140.11,
#    'volumeto': 1932152.42},
#   {'close': 13866.3,
#    'high': 13872.57,
#    'low': 13859.55,
#    'open': 13862.74,
#    'time': 1514463180,
#    'volumefrom': 44.33,
#    'volumeto': 620480.22},
#   {'close': 13850.67,
#    'high': 13870.73,
#    'low': 13850.67,
#    'open': 13866.3,
#    'time': 1514463240,
#    'volumefrom': 31.46,
#    'volumeto': 438807.14}],
#  'FirstValueInArray': True,
#  'Response': 'Success',
#  'TimeFrom': 1514459640,
#  'TimeTo': 1514463240,
#  'Type': 100}

# %%
ts = int(time.time())
ts = ts - (7*23*60*60)

# %%
dfb = pd.DataFrame(columns=['close','high','low','open','time','volumefrom','volumeto'])
dfe = pd.DataFrame(columns=['close','high','low','open','time','volumefrom','volumeto'])
dfm = pd.DataFrame(columns=['close','high','low','open','time','volumefrom','volumeto'])
dfmb = pd.DataFrame(columns=['close','high','low','open','time','volumefrom','volumeto'])

# %%
while ts < time.time():
    try:
        btc = get_info(ts,'BTC')
        eth = get_info(ts,'ETH')    
        monero = get_info(ts,'XMR')  
        monerobt = get_info(ts,'XMR','BTC')
        sleep(0.5)
        for x in range(0, 60):
            dfb = dfb.append(btc['Data'][x],ignore_index=True)
            dfe = dfe.append(eth['Data'][x],ignore_index=True)        
            dfm = dfm.append(monero['Data'][x],ignore_index=True)        
            dfmb = dfmb.append(monerobt['Data'][x],ignore_index=True)        
        ts = ts + 60*60
        dfb.to_csv('btc.csv')
        dfe.to_csv('eth.csv')    
        dfm.to_csv('xmr.csv')    
        dfmb.to_csv('xmrbtc.csv')    
        print(datetime.datetime.fromtimestamp(
            ts
        ).strftime('%Y-%m-%d %H:%M:%S'))
    except:
        pass
# Out:
# 2017-12-21 23:58:19
# 2017-12-22 00:58:19
# 2017-12-22 01:58:19
# 2017-12-22 02:58:19
# 2017-12-22 03:58:19
# 2017-12-22 04:58:19
# 2017-12-22 05:58:19
# 2017-12-22 06:58:19
# 2017-12-22 07:58:19
# 2017-12-22 08:58:19
# 2017-12-22 09:58:19
# 2017-12-22 10:58:19
# 2017-12-22 11:58:19
# 2017-12-22 12:58:19
# 2017-12-22 13:58:19
# 2017-12-22 14:58:19
# 2017-12-22 15:58:19
# 2017-12-22 16:58:19
# 2017-12-22 17:58:19
# 2017-12-22 18:58:19
# 2017-12-22 19:58:19
# 2017-12-22 20:58:19
# 2017-12-22 21:58:19
# 2017-12-22 22:58:19
# 2017-12-22 23:58:19
# 2017-12-23 00:58:19
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-7-89489b57122d> in <module>()
#       1 while ts < time.time():
#       2     btc = get_info(ts,'BTC')
# ----> 3     eth = get_info(ts,'ETH')
#       4     monero = get_info(ts,'XMR')
#       5     monerobt = get_info(ts,'XMR','BTC')
#
# <ipython-input-3-9009f4a513bb> in get_info(time, currency, currency2)
#       1 def get_info(time, currency, currency2='USD'):
# ----> 2     data = json.load(urllib.request.urlopen(base_url + f'data/histominute?fsym={currency}&tsym={currency2}&limit=60&e=CCCAGG&toTs={time}'))
#       3     return data
#
# /usr/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# /usr/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# /usr/lib/python3.6/urllib/request.py in http_response(self, request, response)
#     640         if not (200 <= code < 300):
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#     644         return response
#
# /usr/lib/python3.6/urllib/request.py in error(self, proto, *args)
#     568         if http_err:
#     569             args = (dict, 'default', 'http_error_default') + orig_args
# --> 570             return self._call_chain(*args)
#     571
#     572 # XXX probably also want an abstract factory that knows when it makes
#
# /usr/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# /usr/lib/python3.6/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     648 class HTTPDefaultErrorHandler(BaseHandler):
#     649     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 650         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     651
#     652 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 504: Gateway Time-out
